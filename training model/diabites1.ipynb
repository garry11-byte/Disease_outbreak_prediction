# %% [markdown]
# ## this is predection model for diabetes

# %% [markdown]
# ## importing libraries

# %%
from sklearn.svm import SVC 
from sklearn.model_selection import RandomizedSearchCV

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,precision_score,recall_score,f1_score,roc_auc_score

# %%
db_dataset = pd.read_csv("../dataset/diabetes.csv")

# %% [markdown]
# ## Analysing data using various comands

# %%
db_dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
db_dataset.shape
# Out:
# (768, 9)

# %%
db_dataset.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
db_dataset['Outcome']
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
db_dataset['Outcome'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64>

# %%
db_dataset.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %% [markdown]
# ## training the machine learning model

# %%
x = db_dataset.drop(columns=['Outcome'],axis = 1)  ##storing all the parameters in x expect the outcome columns axis 1 for columns and axis 0 for row
y = db_dataset['Outcome'] ## storing the outcome coloumns in y

# %%
x_train,x_test,y_train,y_test =train_test_split(x,y,test_size=0.2,random_state=42)
## above line gives 4 parameter so we have used 4 xtrain,test and y train,test

# %%
x_train.shape  ## these many data samples for traning data
# Out:
# (614, 8)

# %%
x_test.shape  ## these many data samples for testing the data
# Out:
# (154, 8)

# %%
##random

# %%
#(y_pred = model.predict(x_test)

# Evaluate the model's accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy) 

# Example of how to predict for new data (replace with your actual new data)
new_data = [[200,5,7], [294,7.4,16]] 
predicted_quality = model.predict(new_data)
print("Predicted Quality:", predicted_quality))
# Out:
#   Cell In[53], line 10
#     print("Predicted Quality:", predicted_quality))
#                                                   ^
# SyntaxError: unmatched ')'

# %%
model.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
pip install pickle
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000023DD6CF0590>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/pickle/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000023DD6C8E350>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/pickle/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000023DD6C8E5D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/pickle/
# ...

# %%
import pickle
filename = 'db_dataset.sav'
pickle.dump(model,open(filename,'wb'))

# %% [markdown]
# RandomSerachCV

# %%
model=SVC()

# %%
#hyperparamter
parameters={
    'kernel':['linear','poly','rbf','sigmoid'],
    'C':[1,5,10,20]
}

# %%
classifier= RandomizedSearchCV(model,parameters,cv=5)

# %%
classifier.fit(x,y)
# Out:
# RandomizedSearchCV(cv=5, estimator=SVC(),
#                    param_distributions={'C': [1, 5, 10, 20],
#                                         'kernel': ['linear', 'poly', 'rbf',
#                                                    'sigmoid']})

# %%
classifier.cv_results_
# Out:
# {'mean_fit_time': array([1.12167835e-02, 1.91964626e-02, 4.59533706e+00, 2.12559462e-01,
#         1.53612389e+01, 1.34548187e-02, 9.94433880e-02, 1.11328125e-02,
#         9.95340347e-03, 3.60261516e+01]),
#  'std_fit_time': array([1.41081361e-03, 6.28468739e-03, 1.63361696e+00, 1.08732067e-01,
#         6.38551984e-01, 1.75157042e-03, 3.85934607e-02, 1.15587710e-03,
#         6.14521889e-04, 1.42174423e+01]),
#  'mean_score_time': array([0.0064157 , 0.00287466, 0.00322809, 0.0035193 , 0.00290918,
#         0.0066462 , 0.0032588 , 0.00418129, 0.00661654, 0.00312395]),
#  'std_score_time': array([0.00036305, 0.00033523, 0.00084967, 0.00058952, 0.00037579,
#         0.00161807, 0.00044657, 0.00062877, 0.00072436, 0.00058539]),
#  'param_kernel': masked_array(data=['rbf', 'poly', 'linear', 'poly', 'linear', 'rbf',
#                     'poly', 'sigmoid', 'rbf', 'linear'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
# ...

# %%
best_parameters=classifier.best_params_
print(best_parameters)
# Out:
# {'kernel': 'linear', 'C': 5}

# %%
highest_accuracy=classifier.best_score_
print(highest_accuracy)
# Out:
# 0.7708853238265002

# %%
result=pd.DataFrame(classifier.cv_results_)
print(result)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_kernel  \
# 0       0.011217      0.001411         0.006416        0.000363          rbf
# 1       0.019196      0.006285         0.002875        0.000335         poly
# 2       4.595337      1.633617         0.003228        0.000850       linear
# 3       0.212559      0.108732         0.003519        0.000590         poly
# 4      15.361239      0.638552         0.002909        0.000376       linear
# 5       0.013455      0.001752         0.006646        0.001618          rbf
# 6       0.099443      0.038593         0.003259        0.000447         poly
# 7       0.011133      0.001156         0.004181        0.000629      sigmoid
# 8       0.009953      0.000615         0.006617        0.000724          rbf
# 9      36.026152     14.217442         0.003124        0.000585       linear
#
#    param_C                          params  split0_test_score  \
# ...

# %%
result.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_kernel  \
# 0       0.011217      0.001411         0.006416        0.000363          rbf
# 1       0.019196      0.006285         0.002875        0.000335         poly
# 2       4.595337      1.633617         0.003228        0.000850       linear
# 3       0.212559      0.108732         0.003519        0.000590         poly
# 4      15.361239      0.638552         0.002909        0.000376       linear
#
#    param_C                        params  split0_test_score  \
# 0        5     {'kernel': 'rbf', 'C': 5}           0.746753
# 1        1    {'kernel': 'poly', 'C': 1}           0.759740
# 2        1  {'kernel': 'linear', 'C': 1}           0.759740
# 3       20   {'kernel': 'poly', 'C': 20}           0.759740
# 4        5  {'kernel': 'linear', 'C': 5}           0.753247
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# ...

# %%
randomized_search_results=result[['param_C','param_kernel','mean_test_score']]

# %%
randomized_search_results
# Out:
#    param_C param_kernel  mean_test_score
# 0        5          rbf         0.761769
# 1        1         poly         0.761735
# 2        1       linear         0.765682
# 3       20         poly         0.768229
# 4        5       linear         0.770885
# 5       20          rbf         0.760453
# 6       10         poly         0.764307
# 7       10      sigmoid         0.447984
# 8        1          rbf         0.759146
# 9       10       linear         0.766981
